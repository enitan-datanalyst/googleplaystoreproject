# %% [markdown]
# ## 1. Google Play Store apps and reviews

# %% [markdown]
# # import library

# %%
# we imported our Libaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from google.colab import files 
url = 'https://github.com/adeyeyesaidah/googleplaystore/blob/main/googleplaystore.csv?raw=true'

# %% [markdown]
# #Read in the csv file as a dataframe called df

# %%
df = pd.read_csv(url)
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
#check for missing values
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
#check for the total number of Apps in the dataset
print ('Total number of apps in the dataset = ', len(df))
# Out:
# Total number of apps in the dataset =  10841

# %%
#check for duplicate values
df.duplicated().sum()
# Out:
# 483

# %%
#remove duplicate values
df= df.drop_duplicates() 
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10358 rows x 13 columns]

# %%
#the total number of app after removing duplicate values
print ('Total number of apps in the dataset = ', len(df))
# Out:
# Total number of apps in the dataset =  10358

# %%
# checking for a random sample of the dataset
df.sample(5)
# Out:
#                               App             Category  Rating Reviews  Size  \
# 4834   Space Z 🌏 🚀Icon Pack Theme      PERSONALIZATION     4.8     201   68M
# 5019                  AE FreeCell                 GAME     4.2     358   15M
# 6147               BG TV Stations               FAMILY     NaN       0  2.9M
# 10674   Pistolet FN 1906 expliqué  BOOKS_AND_REFERENCE     NaN       0  5.2M
# 4431        Obbligo o Verità? PRO                 GAME     NaN       4  2.9M
#
#       Installs  Type  Price Content Rating             Genres  \
# 4834    1,000+  Paid  $1.49       Everyone    Personalization
# 5019   10,000+  Free      0       Everyone               Card
# 6147      100+  Free      0       Everyone      Entertainment
# 10674      10+  Paid  $5.49       Everyone  Books & Reference
# 4431      100+  Paid  $0.99           Teen              Board
#
#             Last Updated         Current Ver   Android Ver
# 4834      August 4, 2018               1.2.7  4.0.3 and up
# 5019    November 6, 2014               1.1.5    2.3 and up
# 6147   February 10, 2018                 1.0    4.1 and up
# 10674    August 17, 2014  Android 2.0 - 2014    1.6 and up
# 4431      April 26, 2018                1,01    3.0 and up

# %%
#checking for missing value
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# ## 2. Data cleaning

# %%
#a. Remove special characters from the columns Install and Price

# %%
special_chars = ['+', ',', '$']
cols_to_clean = ['Installs', 'Price']
 
for char in special_chars:
    for cols in cols_to_clean:
        df[cols] = df[cols].apply(lambda x: x.replace(char, ''))

# %%
#b. To confirm special characters have been removed

# %%
#checking the 'Installs' and 'Price' column
df[['Installs', 'Price']]
# Out:
#        Installs Price
# 0         10000     0
# 1        500000     0
# 2       5000000     0
# 3      50000000     0
# 4        100000     0
# ...         ...   ...
# 10836      5000     0
# 10837       100     0
# 10838      1000     0
# 10839      1000     0
# 10840  10000000     0
#
# [10358 rows x 2 columns]

# %%
# Print summary of a dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ## #3. Correcting data types

# %%
#To check data type in the original dataset
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
#unique value of the installs column
df['Installs'].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0', 'Free'],
#       dtype=object)

# %%
#replacing the free in the install column to 0
df['Installs'].replace({'Free':0},inplace=True)

# %%
# changing the install column to float data type
df['Installs']= df['Installs'].astype(float)

# %%
#replacing the everyone in the price column to 0
df['Price'].replace({'Everyone':0},inplace=True)

# %%
# changing the install price to float data type
df['Price']= df['Price'].astype(float)

# %%
#changing the info to confirm the type has been changed
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  float64
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  float64
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 1.1+ MB

# %% [markdown]
# ### 4. Exploring app categories

# %%
#checking the unique no in the category column
category_no = df['Category'].nunique()
category_no
# Out:
# 34

# %%
#checking the Category value counts to know the number of apps in each category and sorting it
app_no= df['Category'].value_counts().sort_values(ascending = False).reset_index()
app_no
# Out:
#                   index  Category
# 0                FAMILY      1943
# 1                  GAME      1121
# 2                 TOOLS       843
# 3              BUSINESS       427
# 4               MEDICAL       408
# 5          PRODUCTIVITY       407
# 6       PERSONALIZATION       388
# 7             LIFESTYLE       373
# 8         COMMUNICATION       366
# 9               FINANCE       360
# 10               SPORTS       351
# 11          PHOTOGRAPHY       322
# 12   HEALTH_AND_FITNESS       306
# 13               SOCIAL       280
# 14   NEWS_AND_MAGAZINES       264
# 15     TRAVEL_AND_LOCAL       237
# 16  BOOKS_AND_REFERENCE       230
# 17             SHOPPING       224
# 18               DATING       196
# 19        VIDEO_PLAYERS       175
# 20  MAPS_AND_NAVIGATION       137
# 21            EDUCATION       130
# 22       FOOD_AND_DRINK       124
# 23        ENTERTAINMENT       111
# 24    AUTO_AND_VEHICLES        85
# 25   LIBRARIES_AND_DEMO        85
# 26              WEATHER        82
# 27       HOUSE_AND_HOME        80
# 28       ART_AND_DESIGN        65
# 29               EVENTS        64
# 30            PARENTING        60
# 31               COMICS        60
# 32               BEAUTY        53
# 33                  1.9         1

# %%
#renaming the columns 
app_sorted= app_no.rename(columns={"index":"Category","Category":"Count"},inplace=True)
app_sorted

# %%
#droping index 33
app_no = app_no.drop([33])

# %%
app_no
# Out:
#                Category  Count
# 0                FAMILY   1943
# 1                  GAME   1121
# 2                 TOOLS    843
# 3              BUSINESS    427
# 4               MEDICAL    408
# 5          PRODUCTIVITY    407
# 6       PERSONALIZATION    388
# 7             LIFESTYLE    373
# 8         COMMUNICATION    366
# 9               FINANCE    360
# 10               SPORTS    351
# 11          PHOTOGRAPHY    322
# 12   HEALTH_AND_FITNESS    306
# 13               SOCIAL    280
# 14   NEWS_AND_MAGAZINES    264
# 15     TRAVEL_AND_LOCAL    237
# 16  BOOKS_AND_REFERENCE    230
# 17             SHOPPING    224
# 18               DATING    196
# 19        VIDEO_PLAYERS    175
# 20  MAPS_AND_NAVIGATION    137
# 21            EDUCATION    130
# 22       FOOD_AND_DRINK    124
# 23        ENTERTAINMENT    111
# 24    AUTO_AND_VEHICLES     85
# 25   LIBRARIES_AND_DEMO     85
# 26              WEATHER     82
# 27       HOUSE_AND_HOME     80
# 28       ART_AND_DESIGN     65
# 29               EVENTS     64
# 30            PARENTING     60
# 31               COMICS     60
# 32               BEAUTY     53

# %%
#ploting Apps against categories
figure = plt.figure(figsize = (14, 8))
plt.xticks(rotation = 90)
title = plt.title('Distribution of Apps across different Categories', color = 'black', fontsize = 20)
sns.barplot(data = app_no, x = 'Category', y = 'Count', palette = 'viridis')
plt.show()

# %% [markdown]
# ## 5. Distribution of app ratings

# %%
df.corr()
# Out:
#             Rating  Installs     Price
# Rating    1.000000  0.048147 -0.021589
# Installs  0.048147  1.000000 -0.011146
# Price    -0.021589 -0.011146  1.000000

# %%
df['Rating'].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
 df[df['Rating']== '19.']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df['Rating'].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
# Mean of Rating including the NaN
avr_Rating = df['Rating'].mean()
avr_Rating
# Out:
# 4.189542336669291

# %%
#Replacing the NaN with the mean of the rating
#values = avr_Rating
#df['Rating'].fillna(value=values,inplace=True)

# %%
#confirming if the values have been filled
#df['Rating'].isna().sum()

# %%
# the mean of the Rating after changing the NaN value
#ave_app_rating = df['Rating'].mean()
#ave_app_rating

# %%
 #show the distribution of rating
 plt.figure(figsize=(10, 5))
 sns.countplot(x='Rating', data=df)
 plt.title('Rating Distribution')
 plt.xticks(rotation=90)
 plt.ylabel('Number of Apps')
 plt.show()

# %%
#The count plot is skewed to the left indicating that the majority of the apps are highly rated 
#with only a few exceptions in the low-rated apps.

# %% [markdown]
# ## 6.Size and price of an app

# %%
#creating a new df where the NaN ROWS are droped
df_noNaN = df.dropna()
df_noNaN
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size    Installs  Type  Price  \
# 0         4.1     159                 19M     10000.0  Free    0.0
# 1         3.9     967                 14M    500000.0  Free    0.0
# 2         4.7   87510                8.7M   5000000.0  Free    0.0
# 3         4.5  215644                 25M  50000000.0  Free    0.0
# 4         4.3     967                2.8M    100000.0  Free    0.0
# ...       ...     ...                 ...         ...   ...    ...
# 10834     4.0       7                2.6M       500.0  Free    0.0
# 10836     4.5      38                 53M      5000.0  Free    0.0
# 10837     5.0       4                3.6M       100.0  Free    0.0
# 10839     4.5     114  Varies with device      1000.0  Free    0.0
# 10840     4.5  398307                 19M  10000000.0  Free    0.0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10834       Everyone                  Education     June 18, 2017
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10834               1.0.0          4.1 and up
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [9360 rows x 13 columns]

# %%
#confirming the NaN as been dropped
df_noNaN.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
#categories with atleast 250 apps
large_category  = df_noNaN.groupby('Category').filter(lambda App : len(App) >= 250)
large_category
# Out:
#                                                  App   Category  Rating  \
# 187                     Visual Voicemail by MetroPCS   BUSINESS     4.1
# 188                                Indeed Job Search   BUSINESS     4.3
# 189                                      Uber Driver   BUSINESS     4.4
# 190                             ADP Mobile Solutions   BUSINESS     4.3
# 191                           Snag - Jobs Hiring Now   BUSINESS     4.3
# ...                                              ...        ...     ...
# 10827                             Fr Agnel Ambarnath     FAMILY     4.2
# 10834                                  FR Calculator     FAMILY     4.0
# 10836                               Sya9a Maroc - FR     FAMILY     4.5
# 10837               Fr. Mike Schmitz Audio Teachings     FAMILY     5.0
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
#        Reviews                Size    Installs  Type  Price Content Rating  \
# 187      16129  Varies with device  10000000.0  Free    0.0       Everyone
# 188     674730  Varies with device  50000000.0  Free    0.0       Everyone
# 189    1254730  Varies with device  10000000.0  Free    0.0       Everyone
# 190      85185                 29M   5000000.0  Free    0.0       Everyone
# 191      32584  Varies with device   1000000.0  Free    0.0       Everyone
# ...        ...                 ...         ...   ...    ...            ...
# 10827      117                 13M      5000.0  Free    0.0       Everyone
# 10834        7                2.6M       500.0  Free    0.0       Everyone
# 10836       38                 53M      5000.0  Free    0.0       Everyone
# 10837        4                3.6M       100.0  Free    0.0       Everyone
# 10840   398307                 19M  10000000.0  Free    0.0       Everyone
#
#           Genres    Last Updated         Current Ver         Android Ver
# 187     Business   July 30, 2018  Varies with device  Varies with device
# 188     Business    May 21, 2018  Varies with device  Varies with device
# 189     Business  August 3, 2018  Varies with device  Varies with device
# 190     Business   July 17, 2018               3.4.2          5.0 and up
# 191     Business     May 4, 2018  Varies with device  Varies with device
# ...          ...             ...                 ...                 ...
# 10827  Education   June 13, 2018              2.0.20        4.0.3 and up
# 10834  Education   June 18, 2017               1.0.0          4.1 and up
# 10836  Education   July 25, 2017                1.48          4.1 and up
# 10837  Education    July 6, 2018                 1.0          4.1 and up
# 10840  Lifestyle   July 25, 2018  Varies with device  Varies with device
#
# [7049 rows x 13 columns]

# %%
# Plot size vs. rating
sizevsrating = sns.jointplot(x = large_category['Size'], y = large_category['Rating'],height=10, ratio=9, space=0.5,)
plt.title('Joint plot of Rating and the app size')
plt.show()

# %%
#creating a df called paid app to show the apps that are paid for
paid_app =df_noNaN[df_noNaN['Type']=='Paid']
paid_app
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 290    TurboScan: scan documents and receipts in PDF            BUSINESS
# 291                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# ...                                              ...                 ...
# 10690                                       FO Bixby     PERSONALIZATION
# 10697                                        Mu.F.O.                GAME
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
#
#        Rating Reviews                Size  Installs  Type  Price  \
# 234       4.7   11442                6.8M  100000.0  Paid   4.99
# 235       4.8   10295                 39M  100000.0  Paid   4.99
# 290       4.7   11442                6.8M  100000.0  Paid   4.99
# 291       4.8   10295                 39M  100000.0  Paid   4.99
# 427       4.0   18247  Varies with device  100000.0  Paid   3.99
# ...       ...     ...                 ...       ...   ...    ...
# 10690     5.0       5                861k     100.0  Paid   0.99
# 10697     5.0       2                 16M       1.0  Paid   0.99
# 10760     4.4      35                2.4M    1000.0  Paid   7.99
# 10782     3.8     252                 11M   10000.0  Paid  16.99
# 10785     4.2    1405                9.5M   10000.0  Paid   1.20
#
#       Content Rating            Genres       Last Updated  Current Ver  \
# 234         Everyone          Business     March 25, 2018        1.5.2
# 235         Everyone          Business     April 11, 2017        3.4.6
# 290         Everyone          Business     March 25, 2018        1.5.2
# 291         Everyone          Business     April 11, 2017        3.4.6
# 427         Everyone     Communication       July 5, 2018  7.5.3.20547
# ...              ...               ...                ...          ...
# 10690       Everyone   Personalization     April 25, 2018          0.2
# 10697       Everyone            Arcade      March 3, 2017          1.0
# 10760       Everyone  Health & Fitness     August 8, 2018        1.9.3
# 10782           Teen            Action  February 27, 2015         2.22
# 10785       Everyone            Puzzle       June 5, 2018          2.7
#
#       Android Ver
# 234    4.0 and up
# 235    3.0 and up
# 290    4.0 and up
# 291    3.0 and up
# 427    4.1 and up
# ...           ...
# 10690  7.0 and up
# 10697  2.3 and up
# 10760  4.2 and up
# 10782  5.0 and up
# 10785  2.3 and up
#
# [645 rows x 13 columns]

# %%
#sorting the price in descending order
paid_app = paid_app.sort_values(by=['Price'], ascending=False)
paid_app
# Out:
#                                                     App         Category  \
# 4367                           I'm Rich - Trump Edition        LIFESTYLE
# 5356                                  I Am Rich Premium          FINANCE
# 4362                                         💎 I'm rich        LIFESTYLE
# 5364                     I am rich (Most expensive app)          FINANCE
# 4197                             most expensive app (H)           FAMILY
# ...                                                 ...              ...
# 7466                                             211:CK             GAME
# 4423                               Planet O - Icon Pack  PERSONALIZATION
# 9170                      Stickman Legends: Shadow Wars             GAME
# 9165  League of Stickman 2018- Ninja Arena PVP(Dream...             GAME
# 7665    Chinese Chess 3D Online (Xiangqi, 象棋, co tuong)             GAME
#
#       Rating Reviews  Size   Installs  Type   Price Content Rating  \
# 4367     3.6     275  7.3M    10000.0  Paid  400.00       Everyone
# 5356     4.1    1867  4.7M    50000.0  Paid  399.99       Everyone
# 4362     3.8     718   26M    10000.0  Paid  399.99       Everyone
# 5364     4.1     129  2.7M     1000.0  Paid  399.99           Teen
# 4197     4.3       6  1.5M      100.0  Paid  399.99       Everyone
# ...      ...     ...   ...        ...   ...     ...            ...
# 7466     5.0       8   38M       10.0  Paid    0.99           Teen
# 4423     4.6     354   24M    10000.0  Paid    0.99       Everyone
# 9170     4.4   38419  100M  1000000.0  Paid    0.99   Everyone 10+
# 9165     4.4   32496   99M  1000000.0  Paid    0.99           Teen
# 7665     3.5      23   37M     1000.0  Paid    0.99       Everyone
#
#                Genres       Last Updated Current Ver   Android Ver
# 4367        Lifestyle        May 3, 2018       1.0.1    4.1 and up
# 5356          Finance  November 12, 2017         1.6    4.0 and up
# 4362        Lifestyle     March 11, 2018       1.0.0    4.4 and up
# 5364          Finance   December 6, 2017           2  4.0.3 and up
# 4197    Entertainment      July 16, 2018         1.0    7.0 and up
# ...               ...                ...         ...           ...
# 7466           Arcade     April 11, 2018         1.3    4.1 and up
# 4423  Personalization      June 13, 2018       1.6.1    4.1 and up
# 9170           Action     August 3, 2018      2.3.24    4.1 and up
# 9165           Action       July 3, 2018       5.3.3    2.3 and up
# 7665            Board  December 27, 2017       2.2.1    4.1 and up
#
# [645 rows x 13 columns]

# %%
#  a jointPlot of Rating vs Price

ratingvsprice = sns.jointplot(x = paid_app ['Price'], y = paid_app ['Rating'],kind='scatter',height=8, ratio=7, space=0.5)

# %% [markdown]
# ## 7. Relation between app category and app price

# %%
plt.figure(figsize=(15, 8))
categoryvsapp = sns.stripplot(x='Price', y = 'Category', data =paid_app,size=5)
plt.title(' Category vs app price')
plt.show()

# %%
#apps greater than $200
Apps_price_200 = paid_app[paid_app['Price']>200]
Apps_price_200
# Out:
#                                  App   Category  Rating Reviews  Size  \
# 4367        I'm Rich - Trump Edition  LIFESTYLE     3.6     275  7.3M
# 5356               I Am Rich Premium    FINANCE     4.1    1867  4.7M
# 4362                      💎 I'm rich  LIFESTYLE     3.8     718   26M
# 5364  I am rich (Most expensive app)    FINANCE     4.1     129  2.7M
# 4197          most expensive app (H)     FAMILY     4.3       6  1.5M
# 5362                   I Am Rich Pro     FAMILY     4.4     201  2.7M
# 5373              I AM RICH PRO PLUS    FINANCE     4.0      36   41M
# 5359              I am rich(premium)    FINANCE     3.5     472  965k
# 5358                      I am Rich!    FINANCE     3.8      93   22M
# 5351                       I am rich  LIFESTYLE     3.8    3547  1.8M
# 5354                  I am Rich Plus     FAMILY     4.0     856  8.7M
# 5369                       I am Rich    FINANCE     4.3     180  3.8M
# 5366                       I Am Rich     FAMILY     3.6     217  4.9M
# 5357             I am extremely Rich  LIFESTYLE     2.9      41  2.9M
# 5355                   I am rich VIP  LIFESTYLE     3.8     411  2.6M
#
#       Installs  Type   Price Content Rating         Genres       Last Updated  \
# 4367   10000.0  Paid  400.00       Everyone      Lifestyle        May 3, 2018
# 5356   50000.0  Paid  399.99       Everyone        Finance  November 12, 2017
# 4362   10000.0  Paid  399.99       Everyone      Lifestyle     March 11, 2018
# 5364    1000.0  Paid  399.99           Teen        Finance   December 6, 2017
# 4197     100.0  Paid  399.99       Everyone  Entertainment      July 16, 2018
# 5362    5000.0  Paid  399.99       Everyone  Entertainment       May 30, 2017
# 5373    1000.0  Paid  399.99       Everyone        Finance      June 25, 2018
# 5359    5000.0  Paid  399.99       Everyone        Finance        May 1, 2017
# 5358    1000.0  Paid  399.99       Everyone        Finance  December 11, 2017
# 5351  100000.0  Paid  399.99       Everyone      Lifestyle   January 12, 2018
# 5354   10000.0  Paid  399.99       Everyone  Entertainment       May 19, 2018
# 5369    5000.0  Paid  399.99       Everyone        Finance     March 22, 2018
# 5366   10000.0  Paid  389.99       Everyone  Entertainment      June 22, 2018
# 5357    1000.0  Paid  379.99       Everyone      Lifestyle       July 1, 2018
# 5355   10000.0  Paid  299.99       Everyone      Lifestyle      July 21, 2018
#
#      Current Ver   Android Ver
# 4367       1.0.1    4.1 and up
# 5356         1.6    4.0 and up
# 4362       1.0.0    4.4 and up
# 5364           2  4.0.3 and up
# 4197         1.0    7.0 and up
# 5362        1.54    1.6 and up
# 5373       1.0.2    4.1 and up
# 5359         3.4    4.4 and up
# 5358         1.0    4.1 and up
# 5351         2.0  4.0.3 and up
# 5354         3.0    4.4 and up
# 5369         1.0    4.2 and up
# 5366         1.5    4.2 and up
# 5357         1.0    4.0 and up
# 5355       1.1.1    4.3 and up

# %%
#selected a particular columns of apps greater tha $200
Apps_price_morethan200_selected = Apps_price_200.iloc[:,[0,1,7]]
Apps_price_morethan200_selected
# Out:
#                                  App   Category   Price
# 4367        I'm Rich - Trump Edition  LIFESTYLE  400.00
# 5356               I Am Rich Premium    FINANCE  399.99
# 4362                      💎 I'm rich  LIFESTYLE  399.99
# 5364  I am rich (Most expensive app)    FINANCE  399.99
# 4197          most expensive app (H)     FAMILY  399.99
# 5362                   I Am Rich Pro     FAMILY  399.99
# 5373              I AM RICH PRO PLUS    FINANCE  399.99
# 5359              I am rich(premium)    FINANCE  399.99
# 5358                      I am Rich!    FINANCE  399.99
# 5351                       I am rich  LIFESTYLE  399.99
# 5354                  I am Rich Plus     FAMILY  399.99
# 5369                       I am Rich    FINANCE  399.99
# 5366                       I Am Rich     FAMILY  389.99
# 5357             I am extremely Rich  LIFESTYLE  379.99
# 5355                   I am rich VIP  LIFESTYLE  299.99

# %%
#popular app categories
popular_app_cats = df[df.Category.isin(['GAME', 'FAMILY', 'PHOTOGRAPHY','MEDICAL', 'TOOLS', 'FINANCE','LIFESTYLE','BUSINESS'])]
popular_app_cats
# Out:
#                                                  App   Category  Rating  \
# 187                     Visual Voicemail by MetroPCS   BUSINESS     4.1
# 188                                Indeed Job Search   BUSINESS     4.3
# 189                                      Uber Driver   BUSINESS     4.4
# 190                             ADP Mobile Solutions   BUSINESS     4.3
# 191                           Snag - Jobs Hiring Now   BUSINESS     4.3
# ...                                              ...        ...     ...
# 10835                                       FR Forms   BUSINESS     NaN
# 10836                               Sya9a Maroc - FR     FAMILY     4.5
# 10837               Fr. Mike Schmitz Audio Teachings     FAMILY     5.0
# 10838                         Parkinson Exercices FR    MEDICAL     NaN
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
#        Reviews                Size    Installs  Type  Price Content Rating  \
# 187      16129  Varies with device  10000000.0  Free    0.0       Everyone
# 188     674730  Varies with device  50000000.0  Free    0.0       Everyone
# 189    1254730  Varies with device  10000000.0  Free    0.0       Everyone
# 190      85185                 29M   5000000.0  Free    0.0       Everyone
# 191      32584  Varies with device   1000000.0  Free    0.0       Everyone
# ...        ...                 ...         ...   ...    ...            ...
# 10835        0                9.6M        10.0  Free    0.0       Everyone
# 10836       38                 53M      5000.0  Free    0.0       Everyone
# 10837        4                3.6M       100.0  Free    0.0       Everyone
# 10838        3                9.5M      1000.0  Free    0.0       Everyone
# 10840   398307                 19M  10000000.0  Free    0.0       Everyone
#
#           Genres        Last Updated         Current Ver         Android Ver
# 187     Business       July 30, 2018  Varies with device  Varies with device
# 188     Business        May 21, 2018  Varies with device  Varies with device
# 189     Business      August 3, 2018  Varies with device  Varies with device
# 190     Business       July 17, 2018               3.4.2          5.0 and up
# 191     Business         May 4, 2018  Varies with device  Varies with device
# ...          ...                 ...                 ...                 ...
# 10835   Business  September 29, 2016               1.1.5          4.0 and up
# 10836  Education       July 25, 2017                1.48          4.1 and up
# 10837  Education        July 6, 2018                 1.0          4.1 and up
# 10838    Medical    January 20, 2017                 1.0          2.2 and up
# 10840  Lifestyle       July 25, 2018  Varies with device  Varies with device
#
# [5965 rows x 13 columns]

# %%
 #Examining the price trend by plotting Price vs Category of the popular app
 plt.figure(figsize=(15, 8))
 ax= sns.stripplot(x = popular_app_cats['Price'], y = popular_app_cats['Category'], jitter=True, linewidth=1) 
ax.set_title('App pricing trend across categories')
plt.show()

# %% [markdown]
# ### 8. Filter out "junk" apps

# %%
#selecting app less than $100
app_priced_below100 =paid_app[paid_app['Price']<100]
app_priced_below100
# Out:
#                                                     App         Category  \
# 2365                          Vargo Anesthesia Mega App          MEDICAL
# 2253                          Vargo Anesthesia Mega App          MEDICAL
# 2414                                       LTC AS Legal          MEDICAL
# 5360                                   I am Rich Person        LIFESTYLE
# 2301                            A Manual of Acupuncture          MEDICAL
# ...                                                 ...              ...
# 7466                                             211:CK             GAME
# 4423                               Planet O - Icon Pack  PERSONALIZATION
# 9170                      Stickman Legends: Shadow Wars             GAME
# 9165  League of Stickman 2018- Ninja Arena PVP(Dream...             GAME
# 7665    Chinese Chess 3D Online (Xiangqi, 象棋, co tuong)             GAME
#
#       Rating Reviews  Size   Installs  Type  Price Content Rating  \
# 2365     4.6      92   32M     1000.0  Paid  79.99       Everyone
# 2253     4.6      92   32M     1000.0  Paid  79.99       Everyone
# 2414     4.0       6  1.3M      100.0  Paid  39.99       Everyone
# 5360     4.2     134  1.8M     1000.0  Paid  37.99       Everyone
# 2301     3.5     214   68M     1000.0  Paid  33.99       Everyone
# ...      ...     ...   ...        ...   ...    ...            ...
# 7466     5.0       8   38M       10.0  Paid   0.99           Teen
# 4423     4.6     354   24M    10000.0  Paid   0.99       Everyone
# 9170     4.4   38419  100M  1000000.0  Paid   0.99   Everyone 10+
# 9165     4.4   32496   99M  1000000.0  Paid   0.99           Teen
# 7665     3.5      23   37M     1000.0  Paid   0.99       Everyone
#
#                Genres       Last Updated Current Ver   Android Ver
# 2365          Medical      June 18, 2018        19.0  4.0.3 and up
# 2253          Medical      June 18, 2018        19.0  4.0.3 and up
# 2414          Medical      April 4, 2018       3.0.1    4.1 and up
# 5360        Lifestyle      July 18, 2017         1.0  4.0.3 and up
# 2301          Medical    October 2, 2017      2.1.35    4.0 and up
# ...               ...                ...         ...           ...
# 7466           Arcade     April 11, 2018         1.3    4.1 and up
# 4423  Personalization      June 13, 2018       1.6.1    4.1 and up
# 9170           Action     August 3, 2018      2.3.24    4.1 and up
# 9165           Action       July 3, 2018       5.3.3    2.3 and up
# 7665            Board  December 27, 2017       2.2.1    4.1 and up
#
# [630 rows x 13 columns]

# %%
#ploting the app categories below 100 dollars 
plt.figure(figsize=(15, 8))
ax= sns.stripplot(x = app_priced_below100['Price'], y = app_priced_below100['Category'], jitter=True, linewidth=1) 
ax.set_title('App priced below 100 across categories after filtering for junk apps')
plt.show()

# %% [markdown]
# ## 9.Popularity of paid apps vs free apps

# %%
#checking app price
App_price = df_noNaN.iloc[:,[0,1,5,6]]
App_price
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#          Installs  Type
# 0         10000.0  Free
# 1        500000.0  Free
# 2       5000000.0  Free
# 3      50000000.0  Free
# 4        100000.0  Free
# ...           ...   ...
# 10834       500.0  Free
# 10836      5000.0  Free
# 10837       100.0  Free
# 10839      1000.0  Free
# 10840  10000000.0  Free
#
# [9360 rows x 4 columns]

# %%
#subset data of apps that are free
App_price_Free = App_price[App_price['Type']=='Free']
App_price_Free
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#          Installs  Type
# 0         10000.0  Free
# 1        500000.0  Free
# 2       5000000.0  Free
# 3      50000000.0  Free
# 4        100000.0  Free
# ...           ...   ...
# 10834       500.0  Free
# 10836      5000.0  Free
# 10837       100.0  Free
# 10839      1000.0  Free
# 10840  10000000.0  Free
#
# [8715 rows x 4 columns]

# %%
#subset data of apps that are paid
App_price_Paid = App_price[App_price['Type']=='Paid']
App_price_Paid
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 290    TurboScan: scan documents and receipts in PDF            BUSINESS
# 291                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# ...                                              ...                 ...
# 10690                                       FO Bixby     PERSONALIZATION
# 10697                                        Mu.F.O.                GAME
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
#
#        Installs  Type
# 234    100000.0  Paid
# 235    100000.0  Paid
# 290    100000.0  Paid
# 291    100000.0  Paid
# 427    100000.0  Paid
# ...         ...   ...
# 10690     100.0  Paid
# 10697       1.0  Paid
# 10760    1000.0  Paid
# 10782   10000.0  Paid
# 10785   10000.0  Paid
#
# [645 rows x 4 columns]

# %%
# to check the app type that are mostly installed
plt.figure(figsize=(10, 5))
sns.barplot(x= 'Type', y= 'Installs',  data = App_price , palette ='rainbow')
plt.show()

# %% [markdown]
# ### 10. Sentiment analysis of user reviews

# %%
# app data url
url_review = 'https://github.com/adeyeyesaidah/googleplaystore/blob/main/googleplaystore_user_reviews.csv?raw=true'

# %%
#reading the review data as df_review
df_review = pd.read_csv(url_review)

# %%
#checking the head of the data
df_review.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
# merging the two data sets on the app column
df_merged =  df.merge(df_review[['App','Translated_Review','Sentiment',	'Sentiment_Polarity',	'Sentiment_Subjectivity']])
df_merged
# Out:
#                                  App        Category  Rating Reviews  \
# 0                Coloring book moana  ART_AND_DESIGN     3.9     967
# 1                Coloring book moana  ART_AND_DESIGN     3.9     967
# 2                Coloring book moana  ART_AND_DESIGN     3.9     967
# 3                Coloring book moana  ART_AND_DESIGN     3.9     967
# 4                Coloring book moana  ART_AND_DESIGN     3.9     967
# ...                              ...             ...     ...     ...
# 122657  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122658  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122659  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122660  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122661  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
#
#                       Size    Installs  Type  Price Content Rating  \
# 0                      14M    500000.0  Free    0.0       Everyone
# 1                      14M    500000.0  Free    0.0       Everyone
# 2                      14M    500000.0  Free    0.0       Everyone
# 3                      14M    500000.0  Free    0.0       Everyone
# 4                      14M    500000.0  Free    0.0       Everyone
# ...                    ...         ...   ...    ...            ...
# 122657  Varies with device  10000000.0  Free    0.0       Everyone
# 122658  Varies with device  10000000.0  Free    0.0       Everyone
# 122659  Varies with device  10000000.0  Free    0.0       Everyone
# 122660  Varies with device  10000000.0  Free    0.0       Everyone
# 122661  Varies with device  10000000.0  Free    0.0       Everyone
#
#                            Genres      Last Updated         Current Ver  \
# 0       Art & Design;Pretend Play  January 15, 2018               2.0.0
# 1       Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2       Art & Design;Pretend Play  January 15, 2018               2.0.0
# 3       Art & Design;Pretend Play  January 15, 2018               2.0.0
# 4       Art & Design;Pretend Play  January 15, 2018               2.0.0
# ...                           ...               ...                 ...
# 122657                Photography    August 6, 2018  Varies with device
# 122658                Photography    August 6, 2018  Varies with device
# 122659                Photography    August 6, 2018  Varies with device
# 122660                Photography    August 6, 2018  Varies with device
# 122661                Photography    August 6, 2018  Varies with device
#
#                Android Ver                                  Translated_Review  \
# 0             4.0.3 and up  A kid's excessive ads. The types ads allowed a...
# 1             4.0.3 and up                                         It bad >:(
# 2             4.0.3 and up                                               like
# 3             4.0.3 and up                                                NaN
# 4             4.0.3 and up                           I love colors inspyering
# ...                    ...                                                ...
# 122657  Varies with device                                                NaN
# 122658  Varies with device                                                NaN
# 122659  Varies with device                                       Too much ads
# 122660  Varies with device                                Just allow time ...
# 122661  Varies with device                       It's good best gallery phone
#
#        Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0       Negative              -0.250                1.000000
# 1       Negative              -0.725                0.833333
# 2        Neutral               0.000                0.000000
# 3            NaN                 NaN                     NaN
# 4       Positive               0.500                0.600000
# ...          ...                 ...                     ...
# 122657       NaN                 NaN                     NaN
# 122658       NaN                 NaN                     NaN
# 122659  Positive               0.200                0.200000
# 122660   Neutral               0.000                0.000000
# 122661  Positive               0.850                0.450000
#
# [122662 rows x 17 columns]

# %%
#droping the NaN value
df_merged = df_merged.dropna(subset = ['Sentiment', 'Reviews'])
df_merged
# Out:
#                                  App        Category  Rating Reviews  \
# 0                Coloring book moana  ART_AND_DESIGN     3.9     967
# 1                Coloring book moana  ART_AND_DESIGN     3.9     967
# 2                Coloring book moana  ART_AND_DESIGN     3.9     967
# 4                Coloring book moana  ART_AND_DESIGN     3.9     967
# 5                Coloring book moana  ART_AND_DESIGN     3.9     967
# ...                              ...             ...     ...     ...
# 122646  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122652  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122659  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122660  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122661  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
#
#                       Size    Installs  Type  Price Content Rating  \
# 0                      14M    500000.0  Free    0.0       Everyone
# 1                      14M    500000.0  Free    0.0       Everyone
# 2                      14M    500000.0  Free    0.0       Everyone
# 4                      14M    500000.0  Free    0.0       Everyone
# 5                      14M    500000.0  Free    0.0       Everyone
# ...                    ...         ...   ...    ...            ...
# 122646  Varies with device  10000000.0  Free    0.0       Everyone
# 122652  Varies with device  10000000.0  Free    0.0       Everyone
# 122659  Varies with device  10000000.0  Free    0.0       Everyone
# 122660  Varies with device  10000000.0  Free    0.0       Everyone
# 122661  Varies with device  10000000.0  Free    0.0       Everyone
#
#                            Genres      Last Updated         Current Ver  \
# 0       Art & Design;Pretend Play  January 15, 2018               2.0.0
# 1       Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2       Art & Design;Pretend Play  January 15, 2018               2.0.0
# 4       Art & Design;Pretend Play  January 15, 2018               2.0.0
# 5       Art & Design;Pretend Play  January 15, 2018               2.0.0
# ...                           ...               ...                 ...
# 122646                Photography    August 6, 2018  Varies with device
# 122652                Photography    August 6, 2018  Varies with device
# 122659                Photography    August 6, 2018  Varies with device
# 122660                Photography    August 6, 2018  Varies with device
# 122661                Photography    August 6, 2018  Varies with device
#
#                Android Ver                                  Translated_Review  \
# 0             4.0.3 and up  A kid's excessive ads. The types ads allowed a...
# 1             4.0.3 and up                                         It bad >:(
# 2             4.0.3 and up                                               like
# 4             4.0.3 and up                           I love colors inspyering
# 5             4.0.3 and up                                             I hate
# ...                    ...                                                ...
# 122646  Varies with device           Overall great app. Best gallery seen far
# 122652  Varies with device  Recommended, 100% love it, keep good work dev ...
# 122659  Varies with device                                       Too much ads
# 122660  Varies with device                                Just allow time ...
# 122661  Varies with device                       It's good best gallery phone
#
#        Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0       Negative           -0.250000                1.000000
# 1       Negative           -0.725000                0.833333
# 2        Neutral            0.000000                0.000000
# 4       Positive            0.500000                0.600000
# 5       Negative           -0.800000                0.900000
# ...          ...                 ...                     ...
# 122646  Positive            0.475000                0.512500
# 122652  Positive            0.566667                0.733333
# 122659  Positive            0.200000                0.200000
# 122660   Neutral            0.000000                0.000000
# 122661  Positive            0.850000                0.450000
#
# [72615 rows x 17 columns]

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
fig.set_size_inches(11, 8)
ax = sns.boxplot(x = 'Type', y ='Sentiment_Polarity', data =df_merged)
ax.set_title('Sentiment Polarity Distribution')
# Out:
# Text(0.5, 1.0, 'Sentiment Polarity Distribution')

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
fig.set_size_inches(11, 8)
ax = sns.countplot(x = 'Sentiment',hue='Type', data =df_merged)
ax.set_title('Sentiment Count Plot')
plt.show()

# %%
df_merged_Paid = df_merged[df_merged['Type']=='Paid']
df_merged_Paid
# Out:
#                         App         Category  Rating Reviews  Size  Installs  \
# 21470  Farming Simulator 18             GAME     4.5   18125   15M  100000.0
# 21471  Farming Simulator 18             GAME     4.5   18125   15M  100000.0
# 21472  Farming Simulator 18             GAME     4.5   18125   15M  100000.0
# 21473  Farming Simulator 18             GAME     4.5   18125   15M  100000.0
# 21474  Farming Simulator 18             GAME     4.5   18125   15M  100000.0
# ...                     ...              ...     ...     ...   ...       ...
# 36410          BIG Launcher  PERSONALIZATION     4.3     881  5.9M   10000.0
# 36411          BIG Launcher  PERSONALIZATION     4.3     881  5.9M   10000.0
# 36412          BIG Launcher  PERSONALIZATION     4.3     881  5.9M   10000.0
# 36413          BIG Launcher  PERSONALIZATION     4.3     881  5.9M   10000.0
# 36414          BIG Launcher  PERSONALIZATION     4.3     881  5.9M   10000.0
#
#        Type  Price Content Rating                Genres   Last Updated  \
# 21470  Paid   4.99       Everyone  Simulation;Education   July 9, 2018
# 21471  Paid   4.99       Everyone  Simulation;Education   July 9, 2018
# 21472  Paid   4.99       Everyone  Simulation;Education   July 9, 2018
# 21473  Paid   4.99       Everyone  Simulation;Education   July 9, 2018
# 21474  Paid   4.99       Everyone  Simulation;Education   July 9, 2018
# ...     ...    ...            ...                   ...            ...
# 36410  Paid   9.99       Everyone       Personalization  June 20, 2018
# 36411  Paid   9.99       Everyone       Personalization  June 20, 2018
# 36412  Paid   9.99       Everyone       Personalization  June 20, 2018
# 36413  Paid   9.99       Everyone       Personalization  June 20, 2018
# 36414  Paid   9.99       Everyone       Personalization  June 20, 2018
#
#               Current Ver Android Ver  \
# 21470  Varies with device  4.4 and up
# 21471  Varies with device  4.4 and up
# 21472  Varies with device  4.4 and up
# 21473  Varies with device  4.4 and up
# 21474  Varies with device  4.4 and up
# ...                   ...         ...
# 36410               2.5.9  2.1 and up
# 36411               2.5.9  2.1 and up
# 36412               2.5.9  2.1 and up
# 36413               2.5.9  2.1 and up
# 36414               2.5.9  2.1 and up
#
#                                        Translated_Review Sentiment  \
# 21470  Great game!!!!! When I got game great, recentl...  Negative
# 21471  Very good, better graphics would better (more ...  Positive
# 21472  Love game, gyroscope controls work. It gets st...  Positive
# 21473  I enjoy game. But I can't write proper review ...  Negative
# 21474  Great game play far best farm sim problem phon...  Positive
# ...                                                  ...       ...
# 36410      Amazing app. Thanks developers wonderful app.  Positive
# 36411                  Superb Awesome app.very easy use.  Positive
# 36412                            Love simple easy-to-use  Positive
# 36413  Black Friday Deal Sonny Been waiting deal moth...  Positive
# 36414  Not cheap app, extremely well done. The free K...  Positive
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 21470           -0.209091                0.631818
# 21471            0.552000                0.586000
# 21472            0.215238                0.451429
# 21473           -0.094805                0.350649
# 21474            0.300000                0.510000
# ...                   ...                     ...
# 36410            0.600000                0.700000
# 36411            0.811111                0.944444
# 36412            0.250000                0.478571
# 36413            0.016667                0.316667
# 36414            0.220833                0.620833
#
# [370 rows x 17 columns]

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
fig.set_size_inches(10, 5)
ax = sns.countplot(x = 'Sentiment', data =df_merged_Paid )
ax.set_title('Sentiment Count Plot for Paid App')
plt.show()

# %%
df_merged_Free= df_merged[df_merged['Type']=='Free']
df_merged_Free
# Out:
#                                 App        Category  Rating Reviews  \
# 0               Coloring book moana  ART_AND_DESIGN     3.9     967
# 1               Coloring book moana  ART_AND_DESIGN     3.9     967
# 2               Coloring book moana  ART_AND_DESIGN     3.9     967
# 4               Coloring book moana  ART_AND_DESIGN     3.9     967
# 5               Coloring book moana  ART_AND_DESIGN     3.9     967
# ...                             ...             ...     ...     ...
# 41656  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 41657  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 41658  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 41659  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 41660  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
#
#                      Size    Installs  Type  Price Content Rating  \
# 0                     14M    500000.0  Free    0.0       Everyone
# 1                     14M    500000.0  Free    0.0       Everyone
# 2                     14M    500000.0  Free    0.0       Everyone
# 4                     14M    500000.0  Free    0.0       Everyone
# 5                     14M    500000.0  Free    0.0       Everyone
# ...                   ...         ...   ...    ...            ...
# 41656  Varies with device  10000000.0  Free    0.0       Everyone
# 41657  Varies with device  10000000.0  Free    0.0       Everyone
# 41658  Varies with device  10000000.0  Free    0.0       Everyone
# 41659  Varies with device  10000000.0  Free    0.0       Everyone
# 41660  Varies with device  10000000.0  Free    0.0       Everyone
#
#                           Genres      Last Updated         Current Ver  \
# 0      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 4      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 5      Art & Design;Pretend Play  January 15, 2018               2.0.0
# ...                          ...               ...                 ...
# 41656                Photography    August 6, 2018  Varies with device
# 41657                Photography    August 6, 2018  Varies with device
# 41658                Photography    August 6, 2018  Varies with device
# 41659                Photography    August 6, 2018  Varies with device
# 41660                Photography    August 6, 2018  Varies with device
#
#               Android Ver                                  Translated_Review  \
# 0            4.0.3 and up  A kid's excessive ads. The types ads allowed a...
# 1            4.0.3 and up                                         It bad >:(
# 2            4.0.3 and up                                               like
# 4            4.0.3 and up                           I love colors inspyering
# 5            4.0.3 and up                                             I hate
# ...                   ...                                                ...
# 41656  Varies with device           Overall great app. Best gallery seen far
# 41657  Varies with device  Recommended, 100% love it, keep good work dev ...
# 41658  Varies with device                                       Too much ads
# 41659  Varies with device                                Just allow time ...
# 41660  Varies with device                       It's good best gallery phone
#
#       Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0      Negative           -0.250000                1.000000
# 1      Negative           -0.725000                0.833333
# 2       Neutral            0.000000                0.000000
# 4      Positive            0.500000                0.600000
# 5      Negative           -0.800000                0.900000
# ...         ...                 ...                     ...
# 41656  Positive            0.475000                0.512500
# 41657  Positive            0.566667                0.733333
# 41658  Positive            0.200000                0.200000
# 41659   Neutral            0.000000                0.000000
# 41660  Positive            0.850000                0.450000
#
# [40052 rows x 17 columns]

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
fig.set_size_inches(10, 5)
ax = sns.countplot(x = 'Sentiment', data =df_merged_Free )
ax.set_title('Sentiment Count Plot for Free App')
plt.show()

# %% [markdown]
# ### **THE** **END**
